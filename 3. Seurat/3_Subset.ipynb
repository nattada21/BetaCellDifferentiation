# %%
library(dplyr)
library(Seurat)
library(patchwork)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Attaching SeuratObject

# %%
beta <- readRDS("/gpfs/commons/groups/zhu_lab/nattada/data/BetaCellDifferentiationProject/Deep/newpipeline/Seurat/Seurat_merged_beta.rds")
beta
# Out:
# An object of class Seurat
# 50972 features across 333212 samples within 1 assay
# Active assay: RNA (50972 features, 10000 variable features)
#  2 dimensional reductions calculated: pca, umap

# %%
DimPlot(beta, raster=FALSE)
# Out:
# plot without title

# %%
head(beta@meta.data)
dim(beta@meta.data)
table(beta$stage, beta$target)
# Out:
#                  orig.ident nCount_RNA nFeature_RNA percent.mt RNA_snn_res.1
# obj1:01:A1:B5:12 beta       290        268          0.6896552  0
# obj1:01:A1:BF:08 beta       248        235          0.4032258  1
# obj1:01:A1:BI:08 beta       404        353          0.0000000  10
# obj1:01:A1:BI:09 beta       236        217          0.0000000  6
# obj1:01:A1:BQ:09 beta       512        443          0.7812500  5
# obj1:01:A1:BQ:11 beta       232        221          0.4310345  11
#                  seurat_clusters target  stage RNA_snn_res.0.5
# obj1:01:A1:B5:12 1               H3K27ac D41   1
# obj1:01:A1:BF:08 0               H3K27ac D15   0
# obj1:01:A1:BI:08 7               H3K27ac D15   7
# obj1:01:A1:BI:09 3               H3K27ac D22   3
# obj1:01:A1:BQ:09 8               H3K27ac D22   8
# obj1:01:A1:BQ:11 3               H3K27ac D41   3
# [1] 333212      9
#
#       H3K27ac H3K27me3
#   D00   11849     5791
#   D04   28140     6285
#   D07   22695     9839
# ...

# %%
DimPlot(beta, raster=FALSE, group.by = "stage")
# Out:
# plot without title

# %%
sub<-subset(beta, stage=="D12" | stage=="D15" | stage=="D22" | stage=="D41")
sub
DimPlot(sub, raster=FALSE)
# Out:
# An object of class Seurat
# 50972 features across 248609 samples within 1 assay
# Active assay: RNA (50972 features, 10000 variable features)
#  2 dimensional reductions calculated: pca, umap
# plot without title

# %%
DimPlot(sub, raster=FALSE, group.by = "stage")
# Out:
# plot without title

# %%
head(sub)
table(sub$stage, sub$target)
# Out:
#                  orig.ident nCount_RNA nFeature_RNA percent.mt RNA_snn_res.1
# obj1:01:A1:B5:12 beta       290        268          0.6896552  0
# obj1:01:A1:BF:08 beta       248        235          0.4032258  1
# obj1:01:A1:BI:08 beta       404        353          0.0000000  10
# obj1:01:A1:BI:09 beta       236        217          0.0000000  6
# obj1:01:A1:BQ:09 beta       512        443          0.7812500  5
# obj1:01:A1:BQ:11 beta       232        221          0.4310345  11
# obj1:01:A1:C2:06 beta       341        301          0.0000000  8
# obj1:01:A1:CJ:10 beta       284        262          1.7605634  2
# obj1:01:A1:DA:09 beta       418        378          0.0000000  15
# obj1:01:A1:DB:11 beta       327        306          0.3058104  2
#                  seurat_clusters target  stage RNA_snn_res.0.5
# obj1:01:A1:B5:12 1               H3K27ac D41   1
# obj1:01:A1:BF:08 0               H3K27ac D15   0
# obj1:01:A1:BI:08 7               H3K27ac D15   7
# ...

# %%
saveRDS(sub, "Subset_merged_beta.rds")
